# %% [markdown]
# ## Cloud Counselage Live Project : Data Science
#
# ### Sakshi Chahande

# %%
import numpy as np
import pandas as pd

# %%
path= r"C:\Users\saksh\Desktop\DS_DATESET.csv"
df=pd.read_csv(path)
df=pd.DataFrame(df)
df.head(5)
# Out:
#   First Name Last Name      City        State  Zip Code DOB [DD/MM/YYYY]  Age  \
# 0     Barron    Harnes  Kolhapur  Maharashtra    416004       24-09-2000   19
# 1      Velma    Allone      Pune  Maharashtra    411011       23-10-1997   22
# 2    Thibaut  Scotland    Mumbai  Maharashtra    400059       06-02-1996   24
# 3      Retha     Proud   Solapur  Maharashtra    413224       26-12-1999   20
# 4        Del    Pearse    Sangli  Maharashtra    416436       21-09-1996   23
#
#    Gender              Email Address  Contact Number  ...  \
# 0    Male       bharnes0@harvard.edu      6345186600  ...
# 1  Female            vallone1@i2i.jp      2808753102  ...
# 2    Male  tscotland2@opensource.org      2945231918  ...
# 3  Female         rproud3@flavors.me      7507196200  ...
# 4  Female      dpearse4@sakura.ne.jp      6643884281  ...
#
#    Programming Language Known other than Java (one major)  \
# 0                                           HTML/CSS
# 1                                                PHP
# 2                                                  C
# 3                                                PHP
# 4                                             Python
#
#   Have you worked on MySQL or Oracle database Have you studied OOP Concepts  \
# 0                                         Yes                            No
# 1                                          No                           Yes
# 2                                          No                            No
# 3                                          No                           Yes
# 4                                          No                           Yes
#
#   Certifications/Achievement/ Research papers  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Rate your written communication skills [1-10]  \
# 0                                             6
# 1                                            10
# 2                                             8
# 3                                             9
# 4                                             8
#
#   Rate your verbal communication skills [1-10]  \
# 0                                           10
# 1                                            7
# 2                                            6
# 3                                            6
# 4                                            6
#
#   Link to updated Resume (Google/ One Drive link preferred)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    link to Linkedin profile  How Did You Hear About This Internship?  \
# 0                       NaN                                  Twitter
# 1                       NaN                      Ex/Current Employee
# 2                       NaN                                  Twitter
# 3                       NaN                                  Twitter
# 4                       NaN                                 Facebook
#
#         Label
# 0  ineligible
# 1    eligible
# 2  ineligible
# 3  ineligible
# 4  ineligible
#
# [5 rows x 32 columns]

# %%
null_values=pd.DataFrame(df.isnull().sum())
null_values.
# Out:
#                                                         0
# First Name                                              0
# Last Name                                               0
# City                                                    0
# State                                                   0
# Zip Code                                                0
# DOB [DD/MM/YYYY]                                        0
# Age                                                     0
# Gender                                                  0
# Email Address                                           0
# Contact Number                                          0
# Emergency Contact Number                                0
# College name                                            0
# University Name                                         0
# Degree                                                  0
# Major/Area of Study                                     0
# Course Type                                             0
# Which-year are you studying in?                         0
# CGPA/ percentage                                        0
# Expected Graduation-year                                0
# Areas of interest                                       0
# Current Employment Status                               0
# Have you worked core Java                               0
# Programming Language Known other than Java (one...      0
# Have you worked on MySQL or Oracle database             0
# Have you studied OOP Concepts                           0
# Certifications/Achievement/ Research papers         10000
# Rate your written communication skills [1-10]           0
# Rate your verbal communication skills [1-10]            0
# Link to updated Resume (Google/ One Drive link ...  10000
# link to Linkedin profile                            10000
# How Did You Hear About This Internship?                 0
# Label                                                   0

# %%
df.shape
# Out:
# (10000, 32)

# %%
df=df.drop('Certifications/Achievement/ Research papers',axis=1)
df=df.drop('Link to updated Resume (Google/ One Drive link preferred)',axis=1)
df=df.drop('link to Linkedin profile',axis=1)
df
# Out:
#      First Name Last Name      City        State  Zip Code DOB [DD/MM/YYYY]  \
# 0        Barron    Harnes  Kolhapur  Maharashtra    416004       24-09-2000
# 1         Velma    Allone      Pune  Maharashtra    411011       23-10-1997
# 2       Thibaut  Scotland    Mumbai  Maharashtra    400059       06-02-1996
# 3         Retha     Proud   Solapur  Maharashtra    413224       26-12-1999
# 4           Del    Pearse    Sangli  Maharashtra    416436       21-09-1996
# ...         ...       ...       ...          ...       ...              ...
# 9995     Paulie    Wilden    Sangli  Maharashtra    416410       01-06-2000
# 9996     Domini    Napton    Mumbai  Maharashtra    400059       20-07-1998
# 9997     Adoree  Westwick  Kolhapur  Maharashtra    416007       21-03-1998
# 9998    Germain     Imlen    Sangli  Maharashtra    416415       29-01-2000
# 9999     Roanne    Dallow   Solapur  Maharashtra    413224       06-03-1999
#
#       Age  Gender              Email Address  Contact Number  ...  \
# 0      19    Male       bharnes0@harvard.edu      6345186600  ...
# 1      22  Female            vallone1@i2i.jp      2808753102  ...
# 2      24    Male  tscotland2@opensource.org      2945231918  ...
# 3      20  Female         rproud3@flavors.me      7507196200  ...
# 4      23  Female      dpearse4@sakura.ne.jp      6643884281  ...
# ...   ...     ...                        ...             ...  ...
# 9995   19    Male       pwildenrn@sbwire.com      5067103396  ...
# 9996   21  Female   dnaptonro@deviantart.com      9365868127  ...
# 9997   22  Female    awestwickrp@example.com      7088063119  ...
# 9998   20  Female   gimlenrq@theatlantic.com      1662837014  ...
# 9999   21  Female     rdallowrr@bandcamp.com      6837626327  ...
#
#              Areas of interest Current Employment Status  \
# 0     Artificial Intelligence                    Student
# 1             Cloud Computing                    Student
# 2                         IoT                    Student
# 3           Digital Marketing                    Student
# 4             Cloud Computing                    Student
# ...                        ...                       ...
# 9995          Machine Learning                   Student
# 9996           Cyber Security                    Student
# 9997                      IoT                    Student
# 9998          Machine Learning                   Student
# 9999           Cyber Security                    Student
#
#      Have you worked core Java  \
# 0                          Yes
# 1                          Yes
# 2                          Yes
# 3                           No
# 4                           No
# ...                        ...
# 9995                       Yes
# 9996                        No
# 9997                       Yes
# 9998                        No
# 9999                        No
#
#      Programming Language Known other than Java (one major)  \
# 0                                              HTML/CSS
# 1                                                   PHP
# 2                                                     C
# 3                                                   PHP
# 4                                                Python
# ...                                                 ...
# 9995                                         JavaScript
# 9996                                                PHP
# 9997                                                C++
# 9998                                         JavaScript
# 9999                                                  C
#
#      Have you worked on MySQL or Oracle database  \
# 0                                            Yes
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ...                                          ...
# 9995                                         Yes
# 9996                                         Yes
# 9997                                         Yes
# 9998                                         Yes
# 9999                                          No
#
#      Have you studied OOP Concepts  \
# 0                               No
# 1                              Yes
# 2                               No
# 3                              Yes
# 4                              Yes
# ...                            ...
# 9995                           Yes
# 9996                           Yes
# 9997                            No
# 9998                           Yes
# 9999                            No
#
#      Rate your written communication skills [1-10]  \
# 0                                                6
# 1                                               10
# 2                                                8
# 3                                                9
# 4                                                8
# ...                                            ...
# 9995                                             9
# 9996                                             7
# 9997                                             7
# 9998                                             7
# 9999                                             6
#
#       Rate your verbal communication skills [1-10]  \
# 0                                               10
# 1                                                7
# 2                                                6
# 3                                                6
# 4                                                6
# ...                                            ...
# 9995                                             9
# 9996                                             7
# 9997                                             7
# 9998                                             6
# 9999                                            10
#
#       How Did You Hear About This Internship?       Label
# 0                                     Twitter  ineligible
# 1                         Ex/Current Employee    eligible
# 2                                     Twitter  ineligible
# 3                                     Twitter  ineligible
# 4                                    Facebook  ineligible
# ...                                       ...         ...
# 9995                                 Facebook    eligible
# 9996                                   Friend    eligible
# 9997                                Newspaper    eligible
# 9998                                Blog post  ineligible
# 9999                                 Facebook  ineligible
#
# [10000 rows x 29 columns]

# %%
df['Have you worked core Java']=df['Have you worked core Java'].replace({'No': 0, 'Yes': 1})
df['Have you worked on MySQL or Oracle database']=df['Have you worked on MySQL or Oracle database'].replace({'No': 0, 'Yes': 1})
df['Have you studied OOP Concepts']=df['Have you studied OOP Concepts'].replace({'No': 0, 'Yes': 1})

# %%
df.head()
# Out:
#   First Name Last Name      City        State  Zip Code DOB [DD/MM/YYYY]  Age  \
# 0     Barron    Harnes  Kolhapur  Maharashtra    416004       24-09-2000   19
# 1      Velma    Allone      Pune  Maharashtra    411011       23-10-1997   22
# 2    Thibaut  Scotland    Mumbai  Maharashtra    400059       06-02-1996   24
# 3      Retha     Proud   Solapur  Maharashtra    413224       26-12-1999   20
# 4        Del    Pearse    Sangli  Maharashtra    416436       21-09-1996   23
#
#    Gender              Email Address  Contact Number  ...  \
# 0    Male       bharnes0@harvard.edu      6345186600  ...
# 1  Female            vallone1@i2i.jp      2808753102  ...
# 2    Male  tscotland2@opensource.org      2945231918  ...
# 3  Female         rproud3@flavors.me      7507196200  ...
# 4  Female      dpearse4@sakura.ne.jp      6643884281  ...
#
#           Areas of interest Current Employment Status  \
# 0  Artificial Intelligence                    Student
# 1          Cloud Computing                    Student
# 2                      IoT                    Student
# 3        Digital Marketing                    Student
# 4          Cloud Computing                    Student
#
#   Have you worked core Java  \
# 0                         1
# 1                         1
# 2                         1
# 3                         0
# 4                         0
#
#   Programming Language Known other than Java (one major)  \
# 0                                           HTML/CSS
# 1                                                PHP
# 2                                                  C
# 3                                                PHP
# 4                                             Python
#
#   Have you worked on MySQL or Oracle database Have you studied OOP Concepts  \
# 0                                           1                             0
# 1                                           0                             1
# 2                                           0                             0
# 3                                           0                             1
# 4                                           0                             1
#
#   Rate your written communication skills [1-10]  \
# 0                                             6
# 1                                            10
# 2                                             8
# 3                                             9
# 4                                             8
#
#    Rate your verbal communication skills [1-10]  \
# 0                                            10
# 1                                             7
# 2                                             6
# 3                                             6
# 4                                             6
#
#    How Did You Hear About This Internship?       Label
# 0                                  Twitter  ineligible
# 1                      Ex/Current Employee    eligible
# 2                                  Twitter  ineligible
# 3                                  Twitter  ineligible
# 4                                 Facebook  ineligible
#
# [5 rows x 29 columns]

# %%
df['Label']=df['Label'].replace({'ineligible': 0, 'eligible': 1})
df.head(10)
# Out:
#   First Name Last Name      City        State  Zip Code DOB [DD/MM/YYYY]  Age  \
# 0     Barron    Harnes  Kolhapur  Maharashtra    416004       24-09-2000   19
# 1      Velma    Allone      Pune  Maharashtra    411011       23-10-1997   22
# 2    Thibaut  Scotland    Mumbai  Maharashtra    400059       06-02-1996   24
# 3      Retha     Proud   Solapur  Maharashtra    413224       26-12-1999   20
# 4        Del    Pearse    Sangli  Maharashtra    416436       21-09-1996   23
# 5     Farlay    Anstis    Sangli  Maharashtra    416415       12-02-2000   20
# 6      Vanna  Keighley   Solapur  Maharashtra    413224       18-03-2000   20
# 7      Vikki  Ottawell  Kolhapur  Maharashtra    416004       21-07-1998   21
# 8   Stanwood    Ferron    Mumbai  Maharashtra    400055       09-12-1999   20
# 9     Tommie   Rastall  Kolhapur  Maharashtra    416119       28-10-1997   22
#
#    Gender              Email Address  Contact Number  ...  \
# 0    Male       bharnes0@harvard.edu      6345186600  ...
# 1  Female            vallone1@i2i.jp      2808753102  ...
# 2    Male  tscotland2@opensource.org      2945231918  ...
# 3  Female         rproud3@flavors.me      7507196200  ...
# 4  Female      dpearse4@sakura.ne.jp      6643884281  ...
# 5    Male         fanstis5@zdnet.com      8429984749  ...
# 6  Female          vkeighley6@un.org      3929498765  ...
# 7  Female     vottawell7@4shared.com      4906898554  ...
# 8    Male      sferron8@vkontakte.ru      8739225175  ...
# 9    Male    trastall9@canalblog.com      3634744513  ...
#
#           Areas of interest Current Employment Status  \
# 0  Artificial Intelligence                    Student
# 1          Cloud Computing                    Student
# 2                      IoT                    Student
# 3        Digital Marketing                    Student
# 4          Cloud Computing                    Student
# 5                   Python                    Student
# 6              QMS/Testing                    Student
# 7             Data Science                    Student
# 8              QMS/Testing                    Student
# 9                      IoT                    Student
#
#   Have you worked core Java  \
# 0                         1
# 1                         1
# 2                         1
# 3                         0
# 4                         0
# 5                         1
# 6                         1
# 7                         0
# 8                         0
# 9                         1
#
#   Programming Language Known other than Java (one major)  \
# 0                                           HTML/CSS
# 1                                                PHP
# 2                                                  C
# 3                                                PHP
# 4                                             Python
# 5                                                PHP
# 6                                                PHP
# 7                                                C++
# 8                                                C++
# 9                                               .Net
#
#   Have you worked on MySQL or Oracle database Have you studied OOP Concepts  \
# 0                                           1                             0
# 1                                           0                             1
# 2                                           0                             0
# 3                                           0                             1
# 4                                           0                             1
# 5                                           1                             0
# 6                                           1                             0
# 7                                           0                             1
# 8                                           1                             1
# 9                                           0                             1
#
#   Rate your written communication skills [1-10]  \
# 0                                             6
# 1                                            10
# 2                                             8
# 3                                             9
# 4                                             8
# 5                                             6
# 6                                            10
# 7                                             9
# 8                                             9
# 9                                            10
#
#    Rate your verbal communication skills [1-10]  \
# 0                                            10
# 1                                             7
# 2                                             6
# 3                                             6
# 4                                             6
# 5                                             7
# 6                                             7
# 7                                             9
# 8                                            10
# 9                                            10
#
#    How Did You Hear About This Internship? Label
# 0                                  Twitter     0
# 1                      Ex/Current Employee     1
# 2                                  Twitter     0
# 3                                  Twitter     0
# 4                                 Facebook     0
# 5                                  Twitter     0
# 6                                 Facebook     1
# 7                                Newspaper     1
# 8                                    Other     1
# 9                                Blog post     0
#
# [10 rows x 29 columns]

# %%
#Q 2a. Plot number of students who applied for different technologies
dfTech=df['Areas of interest'].value_counts()
dfTech=pd.DataFrame(dfTech)

# %%
dfTech
# Out:
#                           Areas of interest
# DevOps                                  674
# Machine Learning                        671
# Python                                  652
# Cyber Security                          638
# Web Development                         637
# QMS/Testing                             633
# Mobility                                631
# IoT                                     630
# Artificial Intelligence                 627
# Digital Marketing                       624
# Blockchain                              623
# Big Data                                612
# Data Science                            601
# Information Security                    598
# RPA                                     589
# Cloud Computing                         560

# %%
dfTech.rename(columns={'Areas of interest':'Count'},inplace=True)
print(dfTech)
# Out:
#                           Count
# DevOps                      674
# Machine Learning            671
# Python                      652
# Cyber Security              638
# Web Development             637
# QMS/Testing                 633
# Mobility                    631
# IoT                         630
# Artificial Intelligence     627
# Digital Marketing           624
# Blockchain                  623
# Big Data                    612
# Data Science                601
# Information Security        598
# RPA                         589
# Cloud Computing             560

# %%
dfTech = dfTech.rename_axis('Technology').reset_index()
print(dfTech)
# Out:
#                   Technology  Count
# 0                    DevOps     674
# 1           Machine Learning    671
# 2                    Python     652
# 3            Cyber Security     638
# 4           Web Development     637
# 5               QMS/Testing     633
# 6                   Mobility    631
# 7                       IoT     630
# 8   Artificial Intelligence     627
# 9         Digital Marketing     624
# 10               Blockchain     623
# 11                 Big Data     612
# 12             Data Science     601
# 13      Information Security    598
# 14                      RPA     589
# 15          Cloud Computing     560

# %%
dfTech
# Out:
#                   Technology  Count
# 0                    DevOps     674
# 1           Machine Learning    671
# 2                    Python     652
# 3            Cyber Security     638
# 4           Web Development     637
# 5               QMS/Testing     633
# 6                   Mobility    631
# 7                       IoT     630
# 8   Artificial Intelligence     627
# 9         Digital Marketing     624
# 10               Blockchain     623
# 11                 Big Data     612
# 12             Data Science     601
# 13      Information Security    598
# 14                      RPA     589
# 15          Cloud Computing     560

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
fig1=plt.figure(figsize=(10,10))
ax = fig1.add_axes([0,0,1,1])
ax.barh(dfTech['Technology'],dfTech['Count'], align='center',color='#f2a5e0')
ax.set_ylabel('Technology')
ax.set_xlabel('Number of students')
ax.set_yticklabels(dfTech['Technology'])
ax.set_title('Number of students who applied for different technologies')
for i, v in enumerate(dfTech['Count']):
    ax.text(v + 3, i + .25, str(v), color='black',fontsize='12',va='center')
plt.show()

# %%
#Q2b The number of students applied for Data Science who knew 'Python' and who didn’t.
dfDataScience=pd.DataFrame(df.loc[df['Areas of interest']=='Data Science '])
dfDataScience
# Out:
#      First Name     Last Name        City        State  Zip Code  \
# 7         Vikki      Ottawell    Kolhapur  Maharashtra    416004
# 38        Windy        Dallin  NaviMumbai  Maharashtra    400208
# 42         Palm  Kindleysides  NaviMumbai  Maharashtra    400701
# 49    Genevieve        Vittel    Kolhapur  Maharashtra    416001
# 57       Phylis         Knott      Sangli  Maharashtra    416406
# ...         ...           ...         ...          ...       ...
# 9921      Hardy      Larciere  NaviMumbai  Maharashtra    400208
# 9975    Joseito    McCaughran      Sangli  Maharashtra    416406
# 9977  Winifield      Burhouse      Mumbai  Maharashtra    400055
# 9986     Bobbee        Dicker  NaviMumbai  Maharashtra    410206
# 9988     Indira      Tutchell     Solapur  Maharashtra    413002
#
#      DOB [DD/MM/YYYY]  Age  Gender                    Email Address  \
# 7          21-07-1998   21  Female           vottawell7@4shared.com
# 38         31-05-1999   20  Female               wdallin12@admin.ch
# 42         02-07-2000   19    Male       pkindleysides16@jalbum.net
# 49         10-01-2000   20  Female                gvittel1d@sun.com
# 57         20-03-1998   22  Female                 pknott1l@ovh.net
# ...               ...  ...     ...                              ...
# 9921       21-09-1996   23    Male              hlarcierepl@icq.com
# 9975       09-09-2000   19    Male         jmccaughranr3@jalbum.net
# 9977       09-09-1999   20    Male            wburhouser5@baidu.com
# 9986       04-04-1998   22  Female              bdickerre@prweb.com
# 9988       20-11-1998   21  Female  itutchellrg@merriam-webster.com
#
#       Contact Number  ...  Areas of interest Current Employment Status  \
# 7         4906898554  ...      Data Science                    Student
# 38        1842648933  ...      Data Science                    Student
# 42        6769788700  ...      Data Science                    Student
# 49        9098996597  ...      Data Science                    Student
# 57        4554314673  ...      Data Science                    Student
# ...              ...  ...                ...                       ...
# 9921      5705043006  ...      Data Science                    Student
# 9975      1811168739  ...      Data Science                    Student
# 9977      9272410567  ...      Data Science                    Student
# 9986      3351122739  ...      Data Science                    Student
# 9988      3329316826  ...      Data Science                    Student
#
#      Have you worked core Java  \
# 7                            0
# 38                           1
# 42                           1
# 49                           1
# 57                           0
# ...                        ...
# 9921                         1
# 9975                         0
# 9977                         1
# 9986                         0
# 9988                         0
#
#      Programming Language Known other than Java (one major)  \
# 7                                                   C++
# 38                                                  C++
# 42                                                   C#
# 49                                             HTML/CSS
# 57                                             HTML/CSS
# ...                                                 ...
# 9921                                         JavaScript
# 9975                                         JavaScript
# 9977                                           HTML/CSS
# 9986                                             Python
# 9988                                               .Net
#
#      Have you worked on MySQL or Oracle database  \
# 7                                              0
# 38                                             0
# 42                                             1
# 49                                             1
# 57                                             0
# ...                                          ...
# 9921                                           1
# 9975                                           0
# 9977                                           1
# 9986                                           1
# 9988                                           0
#
#      Have you studied OOP Concepts  \
# 7                                1
# 38                               0
# 42                               1
# 49                               0
# 57                               1
# ...                            ...
# 9921                             1
# 9975                             1
# 9977                             1
# 9986                             1
# 9988                             0
#
#      Rate your written communication skills [1-10]  \
# 7                                                9
# 38                                               7
# 42                                               8
# 49                                               8
# 57                                               7
# ...                                            ...
# 9921                                             9
# 9975                                             6
# 9977                                             8
# 9986                                             6
# 9988                                             6
#
#       Rate your verbal communication skills [1-10]  \
# 7                                                9
# 38                                               8
# 42                                              10
# 49                                               6
# 57                                               9
# ...                                            ...
# 9921                                             9
# 9975                                             7
# 9977                                            10
# 9986                                            10
# 9988                                             8
#
#       How Did You Hear About This Internship? Label
# 7                                   Newspaper     1
# 38                                      Other     0
# 42                                      Other     1
# 49                                     Intern     0
# 57                                  Blog post     0
# ...                                       ...   ...
# 9921                                   Intern     1
# 9975                                    Other     0
# 9977                                   Friend     1
# 9986                                    Other     0
# 9988                                Newspaper     0
#
# [601 rows x 29 columns]

# %%
total_lang_count=dfDataScience.count()['First Name']
python_count=dfDataScience[dfDataScience['Programming Language Known other than Java (one major)']=='Python'].count()['Programming Language Known other than Java (one major)']
print(total_lang_count)
not_python=total_lang_count-python_count
print(python_count)
# Out:
# 601
# 66

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0,0,1,1])
ax.bar(['Knows Python','Does not know Python'],[python_count,not_python],width=0.5,color=['#ff8080'])
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 12
               )
plt.show()

# %%
# Q2 c
dfInterest=df["How Did You Hear About This Internship?"].value_counts()
dfInterest=pd.DataFrame(dfInterest)

dfInterest.rename(columns={'How Did You Hear About This Internship?':'Count'},inplace=True)
dfInterest
# Out:
#                      Count
# Intern                1173
# Newspaper             1162
# Twitter               1160
# Blog post             1116
# LinkedIn              1112
# Friend                1109
# Facebook              1084
# Other                 1077
# Ex/Current Employee   1007

# %%
dfInterest.plot.pie(y='Count',figsize=(8,10),legend=None,autopct='%1.2f%%')
plt.ylabel=None
plt.xlabel=None
plt.title('The different ways students learned about this program.')
plt.show()

# %%
# Q2d Students who are in the fourth year and have a CGPA greater than 8.0.
df['Which-year are you studying in?'].value_counts()
dfY4=pd.DataFrame(df.loc[df['Which-year are you studying in?']=='Fourth-year'])

# %%
greater_than_8=dfY4[dfY4['CGPA/ percentage']>=8.00].count()['CGPA/ percentage']
less_than_8=dfY4[dfY4['CGPA/ percentage']<8.00].count()['CGPA/ percentage']

fig3=plt.figure(figsize=(4,5))
ax = fig3.add_axes([0,0,1,1])
plt.title('Fourth year students with CGPA greater than or less than 8.0')
ax.pie([greater_than_8,less_than_8],labels=['Greater than or equal to 8.0', 'Less than 8.0'],autopct='%1.2f%%',explode=[0,0.1],colors=['#5bc0de','#d9534f'])
plt.show()

# %%
# Q 2e Students who applied for Digital Marketing with verbal and written communication score greater than 8.
dfDM=df['Areas of interest']
dfDM=pd.DataFrame(df.loc[df['Areas of interest']=='Digital Marketing '])
dfDM.rename(columns={'Rate your written communication skills [1-10]':'Written','Rate your verbal communication skills [1-10]':'Verbal'},inplace=True)
print(dfDM.count()['First Name'])
# Out:
# 624

# %%
written_count=dfDM[dfDM['Written']>=8].count()['CGPA/ percentage']
verbal_count=dfDM[dfDM['Verbal']>=8].count()['CGPA/ percentage']
written_verbal_count=dfDM[(dfDM['Written']>=8) & (dfDM['Verbal']>=8)].count()['CGPA/ percentage']
print(written_count)
print(verbal_count)
print(written_verbal_count)
# Out:
# 364
# 382
# 220

# %%
fig4=plt.figure(figsize=(6,5))
ax = fig4.add_axes([0,0,1,1])
ax.bar(['Written','Verbal','Both'],[written_count,verbal_count,written_verbal_count],color=['#2af5aa'])
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 12
               )
plt.title('Communication Skills Rating of Digital Marketing Students ')
plt.show()

# %%
# Year-wise and area of study wise classification of students.
dfYearMajor=pd.DataFrame(df['Which-year are you studying in?'])
dfYearMajor.replace({'First-year':'1st Year','Second-year':'2nd Year','Third-year':'3rd Year','Fourth-year':'4th Year'},inplace=True)
#dfYearMajor.rename_axis('Year of Study').reset_index()
dfYearMajor=dfYearMajor.join(df['Major/Area of Study'])
dfYearMajor=dfYearMajor.join(df['State'])
dfYearMajor.rename(columns={'Which-year are you studying in?':'Year','Major/Area of Study':'Major'},inplace=True)
dfYearMajor
# Out:
#           Year                              Major        State
# 0     2nd Year             Electrical Engineering  Maharashtra
# 1     4th Year  Electronics and Telecommunication  Maharashtra
# 2     4th Year             Electrical Engineering  Maharashtra
# 3     2nd Year               Computer Engineering  Maharashtra
# 4     1st Year             Electrical Engineering  Maharashtra
# ...        ...                                ...          ...
# 9995  3rd Year               Computer Engineering  Maharashtra
# 9996  3rd Year               Computer Engineering  Maharashtra
# 9997  2nd Year  Electronics and Telecommunication  Maharashtra
# 9998  4th Year               Computer Engineering  Maharashtra
# 9999  1st Year             Electrical Engineering  Maharashtra
#
# [10000 rows x 3 columns]

# %%
dfYearMajor=dfYearMajor.groupby(["Year","Major"],as_index=False)['State'].count()

# %%
dfYearMajor.rename(columns={'State':'Count'},inplace=True)
dfYearMajor.head(20)
dfYearMajor.set_index(['Year'])
# Out:
#                                       Major  Count
# Year
# 1st Year               Computer Engineering   1470
# 1st Year             Electrical Engineering    490
# 1st Year  Electronics and Telecommunication    550
# 2nd Year               Computer Engineering   1536
# 2nd Year             Electrical Engineering    518
# 2nd Year  Electronics and Telecommunication    496
# 3rd Year               Computer Engineering   1449
# 3rd Year             Electrical Engineering    561
# 3rd Year  Electronics and Telecommunication    453
# 4th Year               Computer Engineering   1516
# 4th Year             Electrical Engineering    464
# 4th Year  Electronics and Telecommunication    497

# %%
dfYearMajor=dfYearMajor.set_index(['Year','Major'],drop=True).unstack('Major')

# %%
dfYearMajor
# Out:
#                         Count                         \
# Major    Computer Engineering Electrical Engineering
# Year
# 1st Year                 1470                    490
# 2nd Year                 1536                    518
# 3rd Year                 1449                    561
# 4th Year                 1516                    464
#
#
# Major    Electronics and Telecommunication
# Year
# 1st Year                               550
# 2nd Year                               496
# 3rd Year                               453
# 4th Year                               497

# %%
fig6=plt.figure(figsize=(20,10))
ax=dfYearMajor.plot(kind='bar',figsize=(20,10),width=0.8,color=['#011875','#017175','#640175'],fontsize=14)
ax.set_title('Year and Major wise classification of Students',fontsize=16)
ax.set_facecolor('white')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=14)
ax.get_yaxis().set_visible(False)
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 14, fontweight='bold'
                
               )

plt.show()

# %%
# Q2f City and college wise classification of students
dfCityCollege=df[['College name','City','State']]
dfCityCollege
# Out:
#                                          College name      City        State
# 0      DY Patil College of Engineering And Technology  Kolhapur  Maharashtra
# 1     Vishwakarma Institute of Information Technology      Pune  Maharashtra
# 2                 Vidyalankar Institute of Technology    Mumbai  Maharashtra
# 3           Brahmdevdada Mane Institute of Technology   Solapur  Maharashtra
# 4                 Rajarambapu Institute of Technology    Sangli  Maharashtra
# ...                                               ...       ...          ...
# 9995              Rajarambapu Institute of Technology    Sangli  Maharashtra
# 9996              St. Francis Institute of Technology    Mumbai  Maharashtra
# 9997   DY Patil College of Engineering And Technology  Kolhapur  Maharashtra
# 9998              Rajarambapu Institute of Technology    Sangli  Maharashtra
# 9999        Brahmdevdada Mane Institute of Technology   Solapur  Maharashtra
#
# [10000 rows x 3 columns]

# %%
dfCityCollege=dfCityCollege.groupby(["City","College name"],as_index=False)['State'].count()
dfCityCollege.rename(columns={'State':'Count'},inplace=True)
dfCityCollege.set_index(['City'])
dfCityCollege.head()
# Out:
#        City                                    College name  Count
# 0  Kolhapur       Bharati Vidyapeeth College of Engineering    834
# 1  Kolhapur  DY Patil College of Engineering And Technology    813
# 2    Mumbai            K. J. Somaiya College of Engineering    220
# 3    Mumbai            Rajiv Gandhi Institute of Technology    201
# 4    Mumbai                    Rizvi College of Engineering    222

# %%
dfCityCollege1=dfCityCollege.set_index(['City','College name'],drop=True)
dfCityCollege1.head()
# Out:
#                                                          Count
# City     College name
# Kolhapur Bharati Vidyapeeth College of Engineering         834
#          DY Patil College of Engineering And Technology    813
# Mumbai   K. J. Somaiya College of Engineering              220
#          Rajiv Gandhi Institute of Technology              201
#          Rizvi College of Engineering                      222

# %%
fig7=plt.figure()
ax=dfCityCollege1.plot(kind='barh',figsize=(12,8),width=0.8,color=['maroon'],fontsize=14)
ax.set_title('No. of students in a college',fontsize=16)
ax.set_facecolor('white')
ax.invert_yaxis()
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=14)
ax.get_yaxis().set_visible(True)
for i, v in enumerate(dfCityCollege['Count']):
    ax.text(v + 3, i + .25, str(v), color='black',fontsize='12',va='center')
plt.show()

# %%
city_names=(dfCityCollege['City'].unique())
print(city_names)
# Out:
# ['Kolhapur' 'Mumbai' 'NaviMumbai' 'Pune' 'Sangli' 'Solapur']

# %%
dfKolhapur=pd.DataFrame(dfCityCollege.loc[dfCityCollege['City']=='Kolhapur'])
dfMumbai=pd.DataFrame(dfCityCollege.loc[dfCityCollege['City']=='Mumbai'])
dfNaviMumbai=pd.DataFrame(dfCityCollege.loc[dfCityCollege['City']=='NaviMumbai'])
dfPune=pd.DataFrame(dfCityCollege.loc[dfCityCollege['City']=='Pune'])
dfSangli=pd.DataFrame(dfCityCollege.loc[dfCityCollege['City']=='Sangli'])
dfSolapur=pd.DataFrame(dfCityCollege.loc[dfCityCollege['City']=='Solapur'])

# %%
city_count=[dfKolhapur.sum()['Count'],dfMumbai.sum()['Count'],dfNaviMumbai.sum()['Count'],dfPune.sum()['Count'],dfSangli.sum()['Count'],dfSolapur.sum()['Count']]
city_count
# Out:
# [1647, 1648, 1678, 1647, 1670, 1710]

# %%
fig8=plt.figure(figsize=(5,5))
ax=fig8.add_axes([0,0,1,1])
ax.bar(city_names,city_count,color='pink')
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 12 
                
               )
    plt.title('Number of students in a city')
plt.show()

# %%
fig9,ax=plt.subplots(3,2,figsize=(15,20))
ax[0,0].pie(dfKolhapur['Count'],labels=dfKolhapur['College name'],autopct='%1.2f%%',textprops={'size': 'smaller'})
ax[0,0].set_title('Kolhapur')
ax[0,1].pie(dfMumbai['Count'],labels=dfMumbai['College name'],autopct='%1.2f%%',textprops={'size': 'smaller'})
ax[0,1].set_title('Mumbai')
ax[1,0].pie(dfNaviMumbai['Count'],labels=dfNaviMumbai['College name'],autopct='%1.2f%%',textprops={'size': 'smaller'})
ax[1,0].set_title('Navi Mumbai')
ax[1,1].pie(dfPune['Count'],labels=dfPune['College name'],autopct='%1.2f%%',textprops={'size': 'smaller'})
ax[1,1].set_title('Pune')
ax[2,0].pie(dfSangli['Count'],labels=dfSangli['College name'],autopct='%1.2f%%',textprops={'size': 'smaller'})
ax[2,0].set_title('Sangli')
ax[2,1].pie(dfSolapur['Count'],labels=dfSolapur['College name'],autopct='%1.2f%%',textprops={'size': 'smaller'})
ax[2,1].set_title('Solapur')

plt.show()

# %%
# Plot the relationship between the CGPA and the target variable
dfCGPA_Target=df[['CGPA/ percentage','Label']]
dfCGPA_Target=dfCGPA_Target.rename(columns={'CGPA/ percentage':'CGPA'})

# %%
#where 0 is ineligible and 1 is eligible
import seaborn as sns
sns.set(color_codes=True)
sns.lmplot(x="CGPA", y="Label",hue='Label',data=dfCGPA_Target)

# %%
#Plot the relationship between the Area of Interest and the target variable
dfArea_Target=df[['Areas of interest','Label','State']]
dfArea_Target=dfArea_Target.groupby(["Areas of interest","Label"],as_index=False)['State'].count()
dfArea_Target.rename(columns={'State':'Count'},inplace=True)

# %%
ax=sns.relplot(x="Areas of interest", y="Count",hue='Label',data=dfArea_Target)
ax.set_xticklabels(rotation=90)

# %%
df_elligible=dfArea_Target.loc[dfArea_Target['Label'] == 1]
df_inelligible=dfArea_Target.loc[dfArea_Target['Label'] == 0]
Labels = df_elligible["Areas of interest"].tolist()
elligible_count=df_elligible["Count"].tolist()
inelligible_count=df_inelligible["Count"].tolist()
df = pd.DataFrame({'Elligible': elligible_count,
                   'Inelligible': inelligible_count}, index=Labels)
ax = df.plot.bar(rot=90,color=['#a83232','#8332a8'],figsize=(10,10))

# %%
#Plot the relationship between the year of study, major, and the target variable.
dfYSMT=df[['Which-year are you studying in?','Major/Area of Study','Label','State']]
dfYSMT=dfYSMT.rename(columns={'Which-year are you studying in?':'Year of Study','Major/Area of Study':'Major','State':'Count'})
dfYSMT.replace({'First-year':'1st Year','Second-year':'2nd Year','Third-year':'3rd Year','Fourth-year':'4th Year',1:'Eligible',0:'Ineligible'},inplace=True)
dfYSMT
# Out:
#      Year of Study                              Major       Label        Count
# 0         2nd Year             Electrical Engineering  ineligible  Maharashtra
# 1         4th Year  Electronics and Telecommunication    eligible  Maharashtra
# 2         4th Year             Electrical Engineering  ineligible  Maharashtra
# 3         2nd Year               Computer Engineering  ineligible  Maharashtra
# 4         1st Year             Electrical Engineering  ineligible  Maharashtra
# ...            ...                                ...         ...          ...
# 9995      3rd Year               Computer Engineering    eligible  Maharashtra
# 9996      3rd Year               Computer Engineering    eligible  Maharashtra
# 9997      2nd Year  Electronics and Telecommunication    eligible  Maharashtra
# 9998      4th Year               Computer Engineering  ineligible  Maharashtra
# 9999      1st Year             Electrical Engineering  ineligible  Maharashtra
#
# [10000 rows x 4 columns]

# %%
dfYSMT=dfYSMT.groupby(["Year of Study","Major","Label"],as_index=False)['Count'].count()

# %%
dfYSMT
# Out:
#    Year of Study                              Major       Label  Count
# 0       1st Year               Computer Engineering  ineligible   1470
# 1       1st Year             Electrical Engineering  ineligible    490
# 2       1st Year  Electronics and Telecommunication  ineligible    550
# 3       2nd Year               Computer Engineering    eligible    818
# 4       2nd Year               Computer Engineering  ineligible    718
# 5       2nd Year             Electrical Engineering    eligible    274
# 6       2nd Year             Electrical Engineering  ineligible    244
# 7       2nd Year  Electronics and Telecommunication    eligible    273
# 8       2nd Year  Electronics and Telecommunication  ineligible    223
# 9       3rd Year               Computer Engineering    eligible    801
# 10      3rd Year               Computer Engineering  ineligible    648
# 11      3rd Year             Electrical Engineering    eligible    302
# 12      3rd Year             Electrical Engineering  ineligible    259
# 13      3rd Year  Electronics and Telecommunication    eligible    246
# 14      3rd Year  Electronics and Telecommunication  ineligible    207
# 15      4th Year               Computer Engineering    eligible    815
# 16      4th Year               Computer Engineering  ineligible    701
# 17      4th Year             Electrical Engineering    eligible    259
# 18      4th Year             Electrical Engineering  ineligible    205
# 19      4th Year  Electronics and Telecommunication    eligible    275
# 20      4th Year  Electronics and Telecommunication  ineligible    222

# %%
dfYSMT=dfYSMT.set_index(['Year of Study','Major','Label'],drop=True).unstack('Major','Label')
dfYSMT
# Out:
#                                         Count                         \
# Major                    Computer Engineering Electrical Engineering
# Year of Study Label
# 1st Year      ineligible                 1470                    490
# 2nd Year      eligible                    818                    274
#               ineligible                  718                    244
# 3rd Year      eligible                    801                    302
#               ineligible                  648                    259
# 4th Year      eligible                    815                    259
#               ineligible                  701                    205
#
#
# Major                    Electronics and Telecommunication
# Year of Study Label
# 1st Year      ineligible                               550
# 2nd Year      eligible                                 273
#               ineligible                               223
# 3rd Year      eligible                                 246
#               ineligible                               207
# 4th Year      eligible                                 275
#               ineligible                               222

# %%
fig14=plt.figure(figsize=(20,10))
ax=dfYSMT.plot(kind='bar',figsize=(20,10),width=0.8,color=['#ffd470','#b8ff70','#70ffc3'],fontsize=14)
ax.set_title('Year and Major wise Eligibilty of Students',fontsize=20)
ax.set_facecolor('white')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=14)
ax.get_yaxis().set_visible(False)
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 14, fontweight='bold'
                
               )

plt.show()

# %%
#3. Identify the best binary classifier to classify data into “eligible/1” and “not eligible/0”.

from sklearn import preprocessing

# %%
dfNew=df
columns=dfNew.columns.tolist()
print(columns)
# Out:
# ['First Name', 'Last Name', 'City', 'State', 'Zip Code', 'DOB', 'Age', 'Gender', 'Email Address', 'Contact Number', 'Emergency Contact Number', 'College name', 'University Name', 'Degree', 'Major', 'Course Type', 'Year', 'CGPA', 'Expected Graduation-year', 'Areas of interest', 'Current Employment Status', 'Java', 'Language', 'Database', 'OOP', 'Certifications/Achievement/ Research papers', 'Written', 'Verbal', 'Link to updated Resume (Google/ One Drive link preferred)', 'link to Linkedin profile', 'Internship Info', 'Label']

# %%
dfNew=dfNew.rename(columns={'DOB [DD/MM/YYYY]':'DOB','Major/Area of Study':'Major','Which-year are you studying in?':'Year',
                      'CGPA/ percentage':'CGPA','Have you worked core Java':'Java',
                      'Programming Language Known other than Java (one major)':'Language',
                      'Have you worked on MySQL or Oracle database':'Database',
                      'Have you studied OOP Concepts':'OOP','Rate your written communication skills [1-10]':'Written',
                      'Rate your verbal communication skills [1-10]':'Verbal','How Did You Hear About This Internship?':'Internship Info'
                     })

# %%
dfNew=dfNew.drop('Certifications/Achievement/ Research papers',axis=1)
dfNew=dfNew.drop('Link to updated Resume (Google/ One Drive link preferred)',axis=1)
dfNew=dfNew.drop('link to Linkedin profile',axis=1)

# %%
dfNew
# Out:
#      First Name Last Name      City        State  Zip Code         DOB  Age  \
# 0        Barron    Harnes  Kolhapur  Maharashtra    416004  24-09-2000   19
# 1         Velma    Allone      Pune  Maharashtra    411011  23-10-1997   22
# 2       Thibaut  Scotland    Mumbai  Maharashtra    400059  06-02-1996   24
# 3         Retha     Proud   Solapur  Maharashtra    413224  26-12-1999   20
# 4           Del    Pearse    Sangli  Maharashtra    416436  21-09-1996   23
# ...         ...       ...       ...          ...       ...         ...  ...
# 9995     Paulie    Wilden    Sangli  Maharashtra    416410  01-06-2000   19
# 9996     Domini    Napton    Mumbai  Maharashtra    400059  20-07-1998   21
# 9997     Adoree  Westwick  Kolhapur  Maharashtra    416007  21-03-1998   22
# 9998    Germain     Imlen    Sangli  Maharashtra    416415  29-01-2000   20
# 9999     Roanne    Dallow   Solapur  Maharashtra    413224  06-03-1999   21
#
#       Gender              Email Address  Contact Number  ...  \
# 0       Male       bharnes0@harvard.edu      6345186600  ...
# 1     Female            vallone1@i2i.jp      2808753102  ...
# 2       Male  tscotland2@opensource.org      2945231918  ...
# 3     Female         rproud3@flavors.me      7507196200  ...
# 4     Female      dpearse4@sakura.ne.jp      6643884281  ...
# ...      ...                        ...             ...  ...
# 9995    Male       pwildenrn@sbwire.com      5067103396  ...
# 9996  Female   dnaptonro@deviantart.com      9365868127  ...
# 9997  Female    awestwickrp@example.com      7088063119  ...
# 9998  Female   gimlenrq@theatlantic.com      1662837014  ...
# 9999  Female     rdallowrr@bandcamp.com      6837626327  ...
#
#              Areas of interest Current Employment Status Java    Language  \
# 0     Artificial Intelligence                    Student    1    HTML/CSS
# 1             Cloud Computing                    Student    1         PHP
# 2                         IoT                    Student    1           C
# 3           Digital Marketing                    Student    0         PHP
# 4             Cloud Computing                    Student    0      Python
# ...                        ...                       ...  ...         ...
# 9995          Machine Learning                   Student    1  JavaScript
# 9996           Cyber Security                    Student    0         PHP
# 9997                      IoT                    Student    1         C++
# 9998          Machine Learning                   Student    0  JavaScript
# 9999           Cyber Security                    Student    0           C
#
#      Database OOP Written  Verbal      Internship Info       Label
# 0           1   0       6      10              Twitter  ineligible
# 1           0   1      10       7  Ex/Current Employee    eligible
# 2           0   0       8       6              Twitter  ineligible
# 3           0   1       9       6              Twitter  ineligible
# 4           0   1       8       6             Facebook  ineligible
# ...       ...  ..     ...     ...                  ...         ...
# 9995        1   1       9       9             Facebook    eligible
# 9996        1   1       7       7               Friend    eligible
# 9997        1   0       7       7            Newspaper    eligible
# 9998        1   1       7       6            Blog post  ineligible
# 9999        0   0       6      10             Facebook  ineligible
#
# [10000 rows x 29 columns]

# %%
dfNew['Java']=dfNew['Java'].replace({'No': 0, 'Yes': 1})
dfNew['Database']=dfNew['Database'].replace({'No': 0, 'Yes': 1})
dfNew['OOP']=dfNew['OOP'].replace({'No': 0, 'Yes': 1})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-20fcfdd7c9ee> in <module>
# ----> 1 dfNew['Java']=dfNew['Java'].replace({'No': 0, 'Yes': 1})
#       2 dfNew['Database']=dfNew['Database'].replace({'No': 0, 'Yes': 1})
#       3 dfNew['OOP']=dfNew['OOP'].replace({'No': 0, 'Yes': 1})
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4362             limit=limit,
#    4363             regex=regex,
# -> 4364             method=method,
#    4365         )
#    4366
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6680
#    6681             return self.replace(
# -> 6682                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6683             )
#    6684         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4362             limit=limit,
#    4363             regex=regex,
# -> 4364             method=method,
#    4365         )
#    4366
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6734                         dest_list=value,
#    6735                         inplace=inplace,
# -> 6736                         regex=regex,
#    6737                     )
#    6738
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     610             return _compare_or_regex_search(values, s, regex)
#     611
# --> 612         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     613
#     614         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#     610             return _compare_or_regex_search(values, s, regex)
#     611
# --> 612         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     613
#     614         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in comp(s, regex)
#     608                     maybe_convert_objects(values), s.asm8, regex
#     609                 )
# --> 610             return _compare_or_regex_search(values, s, regex)
#     611
#     612         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _compare_or_regex_search(a, b, regex)
#    1965         raise TypeError(
#    1966             "Cannot compare types {a!r} and {b!r}".format(
# -> 1967                 a=type_names[0], b=type_names[1]
#    1968             )
#    1969         )
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
dfNew['Label']=dfNew['Label'].replace({'ineligible': 0, 'eligible': 1})
dfNew
# Out:
#      First Name Last Name      City        State  Zip Code         DOB  Age  \
# 0        Barron    Harnes  Kolhapur  Maharashtra    416004  24-09-2000   19
# 1         Velma    Allone      Pune  Maharashtra    411011  23-10-1997   22
# 2       Thibaut  Scotland    Mumbai  Maharashtra    400059  06-02-1996   24
# 3         Retha     Proud   Solapur  Maharashtra    413224  26-12-1999   20
# 4           Del    Pearse    Sangli  Maharashtra    416436  21-09-1996   23
# ...         ...       ...       ...          ...       ...         ...  ...
# 9995     Paulie    Wilden    Sangli  Maharashtra    416410  01-06-2000   19
# 9996     Domini    Napton    Mumbai  Maharashtra    400059  20-07-1998   21
# 9997     Adoree  Westwick  Kolhapur  Maharashtra    416007  21-03-1998   22
# 9998    Germain     Imlen    Sangli  Maharashtra    416415  29-01-2000   20
# 9999     Roanne    Dallow   Solapur  Maharashtra    413224  06-03-1999   21
#
#       Gender              Email Address  Contact Number  ...  \
# 0       Male       bharnes0@harvard.edu      6345186600  ...
# 1     Female            vallone1@i2i.jp      2808753102  ...
# 2       Male  tscotland2@opensource.org      2945231918  ...
# 3     Female         rproud3@flavors.me      7507196200  ...
# 4     Female      dpearse4@sakura.ne.jp      6643884281  ...
# ...      ...                        ...             ...  ...
# 9995    Male       pwildenrn@sbwire.com      5067103396  ...
# 9996  Female   dnaptonro@deviantart.com      9365868127  ...
# 9997  Female    awestwickrp@example.com      7088063119  ...
# 9998  Female   gimlenrq@theatlantic.com      1662837014  ...
# 9999  Female     rdallowrr@bandcamp.com      6837626327  ...
#
#              Areas of interest Current Employment Status Java    Language  \
# 0     Artificial Intelligence                    Student    1    HTML/CSS
# 1             Cloud Computing                    Student    1         PHP
# 2                         IoT                    Student    1           C
# 3           Digital Marketing                    Student    0         PHP
# 4             Cloud Computing                    Student    0      Python
# ...                        ...                       ...  ...         ...
# 9995          Machine Learning                   Student    1  JavaScript
# 9996           Cyber Security                    Student    0         PHP
# 9997                      IoT                    Student    1         C++
# 9998          Machine Learning                   Student    0  JavaScript
# 9999           Cyber Security                    Student    0           C
#
#      Database OOP Written  Verbal      Internship Info Label
# 0           1   0       6      10              Twitter     0
# 1           0   1      10       7  Ex/Current Employee     1
# 2           0   0       8       6              Twitter     0
# 3           0   1       9       6              Twitter     0
# 4           0   1       8       6             Facebook     0
# ...       ...  ..     ...     ...                  ...   ...
# 9995        1   1       9       9             Facebook     1
# 9996        1   1       7       7               Friend     1
# 9997        1   0       7       7            Newspaper     1
# 9998        1   1       7       6            Blog post     0
# 9999        0   0       6      10             Facebook     0
#
# [10000 rows x 29 columns]
